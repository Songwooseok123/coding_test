# %% [markdown]
# # 3으로 나누기, 2로 나누기, 1빼기
# ![image.png](attachment:cf9434f5-dc63-4e28-af31-6353eb3c9e7d.png)

# %% [markdown]
# # 조건 만족하면서 계단 오르기
# - 한번에 1,2 계단만 오를 수 있음
# - 연속된 3개 계단 밟으면 안됨.
# - 마지막 계단 밟아야됨

# %% [markdown]
# - ![image.png](attachment:1f740d20-be7f-41a0-8885-8d78933f84ce.png)

# %% [markdown]
# ![image.png](attachment:996d5dab-4fbd-4f59-8a1a-d85c15683af0.png)
