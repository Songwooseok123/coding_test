# %% [markdown]
# ![image.png](attachment:a36cfbb2-6470-44f0-8937-74907d1a1883.png)

# %% [markdown]
# - 위에서 두번째 사진에 조건문 d!=dist[u] 로 바꿔야됨
# - 세번째 사진 조건문도 마찬가지로 !=로 바꾸고, reverse_dist로 바꿔야됨
